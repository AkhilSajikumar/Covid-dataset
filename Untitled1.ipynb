# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
datas=pd.read_csv('covid_worldwide.csv')

# %%
datas
# Out:
#      Serial Number           Country  Total Cases Total Deaths  \
# 0                1               USA  104,196,861    1,132,935
# 1                2             India   44,682,784      530,740
# 2                3            France   39,524,311      164,233
# 3                4           Germany   37,779,833      165,711
# 4                5            Brazil   36,824,580      697,074
# ..             ...               ...          ...          ...
# 226            227  Diamond Princess          712           13
# 227            228      Vatican City           29          NaN
# 228            229    Western Sahara           10            1
# 229            230        MS Zaandam            9            2
# 230            231           Tokelau            5          NaN
#
#     Total Recovered Active Cases     Total Test     Population
# 0       101,322,779    1,741,147  1,159,832,679    334,805,269
# 1        44,150,289        1,755    915,265,788  1,406,631,776
# ...

# %%
Covid = datas.iloc[0:80, 0:8]

# %%
Covid
# Out:
#     Serial Number       Country  Total Cases Total Deaths Total Recovered  \
# 0               1           USA  104,196,861    1,132,935     101,322,779
# 1               2         India   44,682,784      530,740      44,150,289
# 2               3        France   39,524,311      164,233      39,264,546
# 3               4       Germany   37,779,833      165,711      37,398,100
# 4               5        Brazil   36,824,580      697,074      35,919,372
# ..            ...           ...          ...          ...             ...
# 75             76  Saudi Arabia      827,962        9,574         815,528
# 76             77    Azerbaijan      827,944       10,085         817,654
# 77             78      Paraguay      806,256       19,820             NaN
# 78             79       Bahrain      700,452        1,543         698,400
# 79             80     Sri Lanka      671,989       16,828         655,158
#
#    Active Cases     Total Test     Population
# ...

# %%
Covid.dropna(inplace=True)

# %%
Covid['Total Cases'] = Covid['Total Cases'].replace({',': ''}, regex=True).astype(float)
Covid['Total Deaths'] = Covid['Total Deaths'].replace({',': ''}, regex=True).astype(float)

# %%
data_subset = Covid[['Total Cases', 'Total Deaths']]

# %%
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_subset)

# %%
inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data_scaled)
    inertia.append(kmeans.inertia_)

# Plotting the Elbow Method for Optimal k
plt.figure(figsize=(8, 6))
plt.plot(range(1, 11), inertia, marker='o', color='b')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.grid(True)
plt.show()
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(data_scaled)

# Step 6: Add the cluster labels to the data
Covid['Cluster'] = kmeans.labels_

# Step 7: Visualize the clusters
plt.figure(figsize=(8, 6))
plt.scatter(data_scaled[:, 0], data_scaled[:, 1], c=Covid['Cluster'], cmap='viridis', marker='o')
plt.title('KMeans Clustering of Total Cases and Total Deaths')
plt.xlabel('Scaled Total Cases')
plt.ylabel('Scaled Total Deaths')
plt.colorbar(label='Cluster')
plt.grid(True)
plt.show()

# Optionally, display the cluster centers
cluster_centers = scaler.inverse_transform(kmeans.cluster_centers_)
print("Cluster Centers (original scale):")
print(cluster_centers)

# Display the first few rows of the data with cluster labels
print(Covid.head())
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Cluster Centers (original scale):
# [[3.49133443e+06 3.72846000e+04]
#  [3.00652114e+07 2.77795300e+05]
#  [1.04196861e+08 1.13293500e+06]]
#    Serial Number  Country  Total Cases  Total Deaths Total Recovered  \
# 0              1      USA  104196861.0     1132935.0     101,322,779
# 1              2    India   44682784.0      530740.0      44,150,289
# 2              3   France   39524311.0      164233.0      39,264,546
# ...
